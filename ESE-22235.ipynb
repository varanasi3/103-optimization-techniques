# %%
import scipy as sc
from scipy.optimize import minimize
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Question 2

# %%
from mpl_toolkits.mplot3d import Axes3D

f = lambda x1, x2: 4*x1+6*x2-2*x1**2-2*x1*x2-2*x2**2
x2 = np.linspace(-10,10,100)
x1 = np.linspace(-1,3,100)

X, Y = np.meshgrid(x1,x2)
F = f(X,Y)

fig = plt.figure(figsize=(12,12))
ax = plt.subplot(projection='3d') 
surf = ax.plot_surface(X,Y,F)
fig.colorbar(surf,shrink=0.4)


ax.set_xlabel('x1', labelpad=20)
ax.set_ylabel('x2', labelpad=20)
ax.set_zlabel('f(X)', labelpad=20)


plt.show()

# %%
def f(x):
     return(4*x1+6*x2-2*x1**2-2*x1*x2-2*x2**2)
    
def g(x):
    return ()

def gradient(p,r,err,ite):
    i = 0
    while i < ite:
        x1 = p+r*g(p)  
        print(f"{i+1}th iteration values " ,x1)
        i=i+1
        if (abs(p-x1) < err):
            break
        p = x1    
    
    return x1

print(" the maxima of given function", gradient(1,0.02,0.0001,7))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [38], in <cell line: 19>()
#      15         p = x1
#      17     return x1
# ---> 19 print(" the maxima of given function", gradient(1,0.02,0.0001,7))
#
# Input In [38], in gradient(p, r, err, ite)
#       8 i = 0
#       9 while i < ite:
# ---> 10     x1 = p+r*g(p)
#      11     print(f"{i+1}th iteration values " ,x1)
#      12     i=i+1
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
from scipy.optimize import linprog
Z = [7, 10]
A = [[5, 6], [1, 2]]
b = [3600, 960]


res = linprog(Z, A_ub=A, b_ub=b)
print(res)
# Out:
#      con: array([], dtype=float64)
#      fun: 1.7505585262523557e-09
#  message: 'Optimization terminated successfully.'
#      nit: 9
#    slack: array([3600.,  960.])
#   status: 0
#  success: True
#        x: array([1.85004236e-10, 4.55528875e-11])

# %% [markdown]
# ## Question 1

# %% [markdown]
# ## 1a

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 1b

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 1c

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# shadow price of c2 is more
# so the worth is more when compared to c1
